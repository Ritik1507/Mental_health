# %%
# %pip install boto3
# Out:
# ...
#      ---------------------------------------- 0.0/49.3 kB ? eta -:--:--
#      ------------------------ --------------- 30.7/49.3 kB 1.3 MB/s eta 0:00:01
#      -------------------------------------- 49.3/49.3 kB 831.5 kB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/139.2 kB ? eta -:--:--
#    ----------------------- ---------------- 81.9/139.2 kB 1.5 MB/s eta 0:00:01
#    ---------------------------------------- 139.2/139.2 kB 1.7 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/12.4 MB ? eta -:--:--
#     --------------------------------------- 0.2/12.4 MB 3.3 MB/s eta 0:00:04
#    - -------------------------------------- 0.4/12.4 MB 4.6 MB/s eta 0:00:03
#    -- ------------------------------------- 0.7/12.4 MB 5.2 MB/s eta 0:00:03
#    --- ------------------------------------ 1.1/12.4 MB 5.6 MB/s eta 0:00:03
#    ---- ----------------------------------- 1.4/12.4 MB 5.7 MB/s eta 0:00:02
# ...

# %%
import boto3
import pandas as pd

# %%
s3 = boto3.resource(
    service_name = 's3' ,
    region_name='us-east-1' ,
    aws_access_key_id='AKIA5FTZAKSMZP3U3BON' ,
    aws_secret_access_key='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',
)

# %%
for bucket in s3.buckets.all():
    print(bucket.name)
# Out:
# ritikdatasets
# ritikproject

# %%
# %pip install s3fs
# Out:
# ...
#   Using cached aiohttp-3.9.5-cp38-cp38-win_amd64.whl.metadata (7.7 kB)
# ...
#   Using cached aiosignal-1.3.1-py3-none-any.whl.metadata (4.0 kB)
# ...
#   Using cached attrs-23.2.0-py3-none-any.whl.metadata (9.5 kB)
# ...
#   Using cached frozenlist-1.4.1-cp38-cp38-win_amd64.whl.metadata (12 kB)
# ...
#   Using cached multidict-6.0.5-cp38-cp38-win_amd64.whl.metadata (4.3 kB)
# ...
#   Using cached yarl-1.9.4-cp38-cp38-win_amd64.whl.metadata (32 kB)
# ...
#   Using cached async_timeout-4.0.3-py3-none-any.whl.metadata (4.2 kB)
# ...
#    ---------------------------------------- 0.0/177.6 kB ? eta -:--:--
#    ------ --------------------------------- 30.7/177.6 kB ? eta -:--:--
#    ------------------------- -------------- 112.6/177.6 kB 1.6 MB/s eta 0:00:01
#    -------------------------------- ------- 143.4/177.6 kB 1.1 MB/s eta 0:00:01
#    -------------------------------------  174.1/177.6 kB 952.6 kB/s eta 0:00:01
#    -------------------------------------- 177.6/177.6 kB 890.0 kB/s eta 0:00:00
# ...

# %%
s3.Bucket('ritikdatasets').upload_file(Filename = 'mental_health.csv' , Key='mental_health.csv')

# %%
for obj in s3.Bucket('ritikdatasets').objects.all():
    print(obj)
# Out:
# s3.ObjectSummary(bucket_name='ritikdatasets', key='mental_health.csv')

# %%
obj = s3.Bucket('ritikdatasets').Object('mental_health.csv').get()
foo = pd.read_csv(obj['Body'], index_col=0)
